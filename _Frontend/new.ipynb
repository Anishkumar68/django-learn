# %%
text = "Painting with mixed media and collage with newsprint as texture representing the wind through feathers."
# Split the sentence into words
words = text.split()

# Slice the first 20 words
first_20_words = words[:10]

# Join them back into a single string (optional)
sliced_sentence = ' '.join(first_20_words)

print(sliced_sentence)
# Out:
# Painting with mixed media and collage with newsprint as texture
